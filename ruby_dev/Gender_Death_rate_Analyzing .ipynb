# %%
# Importing the basic libraries
import pandas as pd               # linear algebra
import seaborn as sns             # data visualization
import numpy as np                # data processing
import matplotlib.pyplot as plt   # data visualization
# %matplotlib inline

# Display all the columns of the dataframe
pd.pandas.set_option('display.max_columns',None)

# Ignore and hide warnings
import warnings
warnings.filterwarnings("ignore")

# Change figure size of all the matplotlib visualizations 
from pylab import rcParams
rcParams['figure.figsize'] = 14, 8

# %%
# Load the data 
dataset = pd.read_csv("data_modified.csv")
dataset.head()
# Out:
#    Unnamed: 0    Year  Month    State   Sex     Age_Group  Covid_Deaths  \
# 0        9096  2020.0    1.0  Alabama  Male  Under 1 year           0.0
# 1        9097  2020.0    1.0  Alabama  Male    0-17 years           0.0
# 2        9098  2020.0    1.0  Alabama  Male     1-4 years           0.0
# 3        9099  2020.0    1.0  Alabama  Male    5-14 years           0.0
# 4        9100  2020.0    1.0  Alabama  Male   15-24 years           0.0
#
#    Total_Deaths  Pneumonia_Deaths  Pneumonia_Covid_Deaths  Influenza_Deaths  \
# 0          17.0               0.0                     0.0               0.0
# 1          44.0               0.0                     0.0               NaN
# 2           NaN               0.0                     0.0               0.0
# 3          11.0               0.0                     0.0               0.0
# 4          43.0               0.0                     0.0               NaN
#
#    Pneumonia_Influenza_Covid_Deaths
# 0                               0.0
# ...

# %%
plt.bar(dataset['Sex'],dataset['Total_Deaths'])
# Out:
# <BarContainer object of 27136 artists>

# %%
plt.bar(dataset['Sex'],dataset['Covid_Deaths'])
# Out:
# <BarContainer object of 27136 artists>

# %%
plt.bar(dataset['Month'],dataset['Total_Deaths'])
# Out:
# <BarContainer object of 27136 artists>

# %%
plt.bar(dataset['Month'],dataset['Covid_Deaths'])
# Out:
# <BarContainer object of 27136 artists>

# %%
plt.barh(dataset['Age_Group'],dataset['Total_Deaths'])
# Out:
# <BarContainer object of 27136 artists>

# %%
plt.barh(dataset['Age_Group'],dataset['Covid_Deaths'])
# Out:
# <BarContainer object of 27136 artists>

# %%
plt.barh(dataset['State'],dataset['Total_Deaths'])
# Out:
# <BarContainer object of 27136 artists>
